# %%
import pandas as pd
df = pd.read_csv('meta/test.txt', header=None)
df.columns = ['path']

# %%
df.head()
# Out:
#                 path
# 0  apple_pie/1011328
# 1   apple_pie/101251
# 2  apple_pie/1034399
# 3   apple_pie/103801
# 4  apple_pie/1038694

# %%
# classes = pd.read_csv('meta/classes.txt', header=None)
# classes.columns = ['cls']
# classes.head()
# import os
# for i, row in classes.iterrows():
#     print(row.cls)
#     os.makedirs('test/'+row.cls)
print("okay")
# Out:
# okay

# %%
import matplotlib.pyplot as plt
import shutil

for i, row in df.iterrows():
    print(row.path)
    plt.imshow(plt.imread("images/"+row.path+'.jpg'))
    s = "images/"+row.path+'.jpg'
    d = "test/"+row.path+'.jpg'
    shutil.move(s, d)
    # break
    print(i)
# Out:
# apple_pie/1011328
# 0
# apple_pie/101251
# 1
# apple_pie/1034399
# 2
# apple_pie/103801
# 3
# apple_pie/1038694
# 4
# apple_pie/1047447
# 5
# apple_pie/1068632
# 6
# apple_pie/110043
# 7
# apple_pie/1106961
# 8
# apple_pie/1113017
# 9
# apple_pie/116705
# 10
# apple_pie/1167170
# 11
# apple_pie/1174330
# 12
# apple_pie/1180600
# 13
# apple_pie/1235282
# 14
# apple_pie/1269202
# 15
# apple_pie/1272958
# 16
# apple_pie/1284428
# 17
# apple_pie/1295996
# 18
# apple_pie/129668
# 19
# apple_pie/1321400
# 20
# apple_pie/1327259
# 21
# apple_pie/1332030
# 22
# apple_pie/1364847
# 23
# apple_pie/1375404
# 24
# apple_pie/1398774
# 25
# apple_pie/1420999
# 26
# apple_pie/1429866
# 27
# apple_pie/1444702
# 28
# apple_pie/1461580
# 29
# apple_pie/1469191
# 30
# apple_pie/1472631
# 31
# apple_pie/1510125
# 32
# apple_pie/1510930
# 33
# apple_pie/1514110
# 34
# apple_pie/1526484
# 35
# apple_pie/1578710
# 36
# apple_pie/1579622
# 37
# apple_pie/1579774
# 38
# apple_pie/1617515
# 39
# ...

# %%
print('done')
# Out:
# done
